# %% [markdown]
# # Project 3, Calculating number of customers around BART stations
#
#
# University of California, Berkeley
#
# Master of Information and Data Science (MIDS) program
#
# W205, Section 01 Annie Cui, Emily Zhou, Shuo Wang

# %% [markdown]
# # Overview
#
# Our goal is to increase AGM brand awareness transbay. One of the ways we'll do that is by piloting pick-up points or delivery points at 3 BART stations. In this notebook, we crate the heat map based on intensity of number of customers.

# %% [markdown]
# # BART Map

# %% [markdown]
# ![Bart Map](bart_map.png)

# %% [markdown]
# # Included Modules and Packages
#
# Code cell containing your includes for modules and packages

# %%
import math
import numpy as np
import pandas as pd

import psycopg2

import json

import gmaps
import gmaps.geojson_geometries

from geographiclib.geodesic import Geodesic

# %% [markdown]
# # Supporting code
#
# Code cells containing any supporting code, such as connecting to the database, any functions, etc.

# %%
#
# function to run a select query and return rows in a pandas dataframe
# pandas puts all numeric values from postgres to float
# if it will fit in an integer, change it to integer
#

def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %% [markdown]
# # Connect to Google Maps using your api key; edit the file gmap_api_key.txt and put in your api key

# %%
f = open('gmap_api_key.txt', 'r')
my_api_key = f.read()
f.close()

gmaps.configure(api_key=my_api_key)

# %% [markdown]
# # Basic map centered on Sather Gate at UC Berkeley; all point are (latitude, longitude) in decimal; zoom levels go from 1 to 21; 1 is world level; 21 is street level; default type of map is Road Map

# %%
sather_gate_berkeley = (37.870260430419115, -122.25950168579497)

gmaps.figure(center=sather_gate_berkeley, zoom_level=9)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Find a list of zip codes for all customers of the Berkeley store; distinct removes duplicates

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select distinct z.*
from customers as cu
     join zip_codes as z
         on cu.zip = z.zip
where cu.closest_store_id = 1
order by 1,2

"""

df = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
df
# Out:
#        zip  latitude  longitude           city state  population     area  \
# 0    94002   37.5135  -122.2991        Belmont    CA       27202   5.9244
# 1    94005   37.6887  -122.4080       Brisbane    CA        4692   4.8168
# 2    94010   37.5693  -122.3653     Burlingame    CA       42730  12.4205
# 3    94014   37.6909  -122.4475      Daly City    CA       49515   6.6361
# 4    94015   37.6812  -122.4805      Daly City    CA       64887   6.1247
# ..     ...       ...        ...            ...   ...         ...      ...
# 139  94963   38.0138  -122.6703   San Geronimo    CA         498   2.3307
# 140  94964   37.9431  -122.4918    San Quentin    CA        3418   0.2608
# 141  94965   37.8499  -122.5236      Sausalito    CA       11408  14.2131
# 142  94970   37.9145  -122.6469  Stinson Beach    CA         689   7.0006
# 143  94973   38.0127  -122.6397       Woodacre    CA        1342   3.7411
#
#       density            time_zone
# 0     4591.53  America/Los_Angeles
# 1      974.09  America/Los_Angeles
# 2     3440.28  America/Los_Angeles
# 3     7461.50  America/Los_Angeles
# 4    10594.35  America/Los_Angeles
# ..        ...                  ...
# 139    213.67  America/Los_Angeles
# 140  13104.83  America/Los_Angeles
# 141    802.64  America/Los_Angeles
# 142     98.42  America/Los_Angeles
# 143    358.71  America/Los_Angeles
#
# [144 rows x 9 columns]

# %% [markdown]
# # Find a list of zip codes for customers of the Berkeley store; do not remove duplicates so we can use intensity levels for each zip code

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select *
from stores

"""

df = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
df
# Out:
#    store_id              street       city state    zip  latitude  longitude
# 0         1  3000 Telegraph Ave   Berkeley    CA  94705   37.8555  -122.2604
# 1         2       1001 Broadway    Seattle    WA  98122   47.6114  -122.3214
# 2         3   2510 McKinney Ave     Dallas    TX  75201   32.7958   -96.8015
# 3         4      299 SE 3rd Ave      Miami    FL  33131   25.7720   -80.1891
# 4         5       1202 Broadway  Nashville    TN  37203   36.1568   -86.7881

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select z.latitude, z.longitude
from customers as cu
     join zip_codes as z
         on cu.zip = z.zip
where cu.closest_store_id = 1
order by 1,2

"""

df = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
df
# Out:
#       latitude  longitude
# 0      37.4949  -122.2080
# 1      37.4949  -122.2080
# 2      37.4949  -122.2080
# 3      37.4949  -122.2080
# 4      37.4949  -122.2080
# ...        ...        ...
# 8133   38.1842  -122.2629
# 8134   38.1842  -122.2629
# 8135   38.1842  -122.2629
# 8136   38.1842  -122.2629
# 8137   38.1842  -122.2629
#
# [8138 rows x 2 columns]

# %% [markdown]
# # Heatmap showing intensity as the number of customers in each zip code¶

# %%
fig = gmaps.figure(center=sather_gate_berkeley, zoom_level=8)

heatmap_layer = gmaps.heatmap_layer(df)

fig.add_layer(heatmap_layer)

heatmap_layer.point_radius = 20

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Create datafrme df1
# Subgroups BART stations into 8 bay area regions by zip codes.
#
# Bay area regions:
# Berkeley, Downtown SF, West Oakland, Orinda, Fruitvale, Down Oakland, Central SF, Mission SF

# %%
df1 = pd.read_csv('group_zipcode.csv')
df1
# Out:
#      zips  count             Group
# 0   94102     78       Downtown SF
# 1   94103     77       Downtown SF
# 2   94104      5       Downtown SF
# 3   94108     50       Downtown SF
# 4   94105     48       Downtown SF
# 5   94111     36       Downtown SF
# 6   94133     57       Downtown SF
# 7   94110     75        Mission SF
# 8   94114     58        Mission SF
# 9   94112     40        Central SF
# 10  94131     63        Central SF
# 11  94127     36        Central SF
# 12  94612    161  Downtown Oakland
# 13  94607    203      West Oakland
# 14  94601    180         Fruitvale
# 15  94563    193            Orinda
# 16  94702    171          Berkeley
# 17  94703    155          Berkeley
# 18  94704    161          Berkeley
# 19  94709    117          Berkeley

# %%
df1['zips'] = df1['zips'].astype(str)

# %%
df1.dtypes
# Out:
# zips     object
# count     int64
# Group    object
# dtype: object

# %% [markdown]
# # Create dataframe df_zip to include zip_codes table

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select *
from zip_codes

"""

df_zip = my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
df_zip
# Out:
#          zip  latitude  longitude        city state  population     area  \
# 0      08074   39.7158   -75.1640    Richwood    NJ          15   0.0886
# 1      08240   39.4873   -74.5318      Pomona    NJ        2293   1.5196
# 2      08876   40.5880   -74.6874  Somerville    NJ       22059  15.1172
# 3      10001   40.7506   -73.9972    New York    NY       22924   0.6675
# 4      32026   30.0541   -82.1815     Raiford    FL        1907   0.6333
# ...      ...       ...        ...         ...   ...         ...      ...
# 32718  47367   40.0827   -85.3872    Oakville    IN          23   0.0866
# 32719  63079   38.2606   -91.0998     Stanton    MO          24   0.3523
# 32720  63738   37.0893   -89.9574   Brownwood    MO          31   0.1171
# 32721  68954   40.6227   -98.2374      Inland    NE          14   1.7437
# 32722  72377   35.6876   -90.3385   Rivervale    AR           9   0.1931
#
#         density                     time_zone
# 0        169.39              America/New_York
# 1       1508.93              America/New_York
# 2       1459.20              America/New_York
# 3      34341.44              America/New_York
# 4       3011.38              America/New_York
# ...         ...                           ...
# 32718    265.47  America/Indiana/Indianapolis
# 32719     68.12               America/Chicago
# 32720    264.70               America/Chicago
# 32721      8.03               America/Chicago
# 32722     46.62               America/Chicago
#
# [32723 rows x 9 columns]

# %%
df_zip.dtypes
# Out:
# zip            object
# latitude      float64
# longitude     float64
# city           object
# state          object
# population      Int64
# area          float64
# density       float64
# time_zone      object
# dtype: object

# %% [markdown]
# # Create dataframe df2
# Add latitude and longitude for each zip codes by join dataframes df1 and df_zip

# %%
df2 = pd.merge(df1, df_zip[['zip', 'latitude', 'longitude']], how = 'left', left_on = 'zips', right_on = 'zip')
df2
# Out:
#      zips  count             Group    zip  latitude  longitude
# 0   94102     78       Downtown SF  94102   37.7797  -122.4192
# 1   94103     77       Downtown SF  94103   37.7732  -122.4111
# 2   94104      5       Downtown SF  94104   37.7915  -122.4021
# 3   94108     50       Downtown SF  94108   37.7920  -122.4086
# 4   94105     48       Downtown SF  94105   37.7898  -122.3939
# 5   94111     36       Downtown SF  94111   37.7989  -122.3984
# 6   94133     57       Downtown SF  94133   37.8038  -122.4107
# 7   94110     75        Mission SF  94110   37.7500  -122.4154
# 8   94114     58        Mission SF  94114   37.7580  -122.4354
# 9   94112     40        Central SF  94112   37.7203  -122.4430
# 10  94131     63        Central SF  94131   37.7455  -122.4429
# 11  94127     36        Central SF  94127   37.7357  -122.4594
# 12  94612    161  Downtown Oakland  94612   37.8088  -122.2691
# 13  94607    203      West Oakland  94607   37.8073  -122.3002
# 14  94601    180         Fruitvale  94601   37.7767  -122.2184
# 15  94563    193            Orinda  94563   37.8797  -122.1846
# 16  94702    171          Berkeley  94702   37.8658  -122.2863
# 17  94703    155          Berkeley  94703   37.8639  -122.2756
# 18  94704    161          Berkeley  94704   37.8666  -122.2580
# 19  94709    117          Berkeley  94709   37.8793  -122.2669

# %% [markdown]
# # Create dataframe df_group
#
# - Get average latitude and longitude for each bay area region.
# - Sum the number of customer for each bay area region.

# %%
df_group = df2.groupby('Group').agg({'latitude': 'mean', 'longitude': 'mean','count': 'sum'})
df_group
# Out:
#                    latitude   longitude  count
# Group
# Berkeley          37.868900 -122.271700    604
# Central SF        37.733833 -122.448433    139
# Downtown Oakland  37.808800 -122.269100    161
# Downtown SF       37.789843 -122.406286    351
# Fruitvale         37.776700 -122.218400    180
# Mission SF        37.754000 -122.425400    133
# Orinda            37.879700 -122.184600    193
# West Oakland      37.807300 -122.300200    203

# %%
lag_list = list(df_group.latitude)
lag_list
# Out:
# [37.868900000000004,
#  37.73383333333334,
#  37.8088,
#  37.78984285714286,
#  37.7767,
#  37.754000000000005,
#  37.8797,
#  37.8073]

# %% [markdown]
# # Create df3
# Incluces all the latitude and longitude. This is prepared for heatmap.

# %%
lag_list = list(df_group.latitude)
log_list = list(df_group.longitude)
freq = list(df_group['count'])

df3 = pd.DataFrame()

for lag, log, fq in zip(lag_list, log_list, freq):
    temp_df = pd.DataFrame(data = {'latitude':[lag]*fq,'longitude':[log]*fq})
    df3 = pd.concat([df3, temp_df])

df3
# Out:
#      latitude  longitude
# 0     37.8689  -122.2717
# 1     37.8689  -122.2717
# 2     37.8689  -122.2717
# 3     37.8689  -122.2717
# 4     37.8689  -122.2717
# ..        ...        ...
# 198   37.8073  -122.3002
# 199   37.8073  -122.3002
# 200   37.8073  -122.3002
# 201   37.8073  -122.3002
# 202   37.8073  -122.3002
#
# [1964 rows x 2 columns]

# %%
df_group['count'].sum()
# Out:
# 1964

# %%
df3['latitude'].value_counts(dropna = False)
# Out:
# 37.868900    604
# 37.789843    351
# 37.807300    203
# 37.879700    193
# 37.776700    180
# 37.808800    161
# 37.733833    139
# 37.754000    133
# Name: latitude, dtype: int64

# %%
df3['longitude'].value_counts(dropna = False)
# Out:
# -122.271700    604
# -122.406286    351
# -122.300200    203
# -122.184600    193
# -122.218400    180
# -122.269100    161
# -122.448433    139
# -122.425400    133
# Name: longitude, dtype: int64

# %% [markdown]
# # Heatmap showing intensity as the number of customers in each bay area region

# %%
fig = gmaps.figure(center=sather_gate_berkeley, zoom_level=12)

heatmap_layer = gmaps.heatmap_layer(df3)

fig.add_layer(heatmap_layer)

heatmap_layer.point_radius = 50

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
